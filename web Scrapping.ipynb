# %% [markdown]
# <a href="https://cognitiveclass.ai/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkRP0321ENSkillsNetwork25371262-2021-01-01">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-RP0101EN-Coursera/v2/M1_R_Basics/images/IDSNlogo.png" width="200" align="center">
# </a>

# %% [markdown]
# <h1>Web scrape a Global Bike-Sharing Systems Wiki Page</h1>
#
# Estimated time needed: **20** minutes

# %% [markdown]
# ## Lab Overview:
#
# Before getting your hands dirty on the actual data analysis tasks, you first need to obtain some background and context information about well-known bike sharing systems worldwide, such as their location, launch date, rental bike size, and so on.
#
# You can get such information from this Wiki page:
#
# [https://en.wikipedia.org/wiki/List_of_bicycle-sharing_systems](https://en.wikipedia.org/wiki/List_of_bicycle-sharing_systems?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkRP0321ENSkillsNetwork25371262-2021-01-01)
#
# <a href="https://cognitiveclass.ai/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkRP0321ENSkillsNetwork25371262-2021-01-01">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-RP0321EN-SkillsNetwork/labs/module_1/images/l2-list-bike-sharing-systems.png" width="600" align="center">
# </a>

# %% [markdown]
# First import necessary libraries for the webscraping task.

# %% [markdown]
# In this lab, you need to use the `rvest` library to obtain the bike sharing systems table from the above web page, convert the table into a data frame, and write the data frame to a csv file for future data wrangling and analysis tasks.

# %%
# Check if need to install rvest` library
require("rvest")

library(rvest)
# Out:
# Loading required package: rvest
# Loading required package: xml2
# Registered S3 method overwritten by 'rvest':
#   method            from
#   read_xml.response xml2

# %% [markdown]
# # TASK: Extract bike sharing systems HTML table from a Wiki page and convert it into a data frame

# %% [markdown]
# *TODO:* Get the root HTML node

# %%
url <- "https://en.wikipedia.org/wiki/List_of_bicycle-sharing_systems"
# Get the root HTML node by calling the `read_html()` method with URL
root_node<-read_html(url)
root_node
# Out:
# {xml_document}
# <html class="client-nojs" lang="en" dir="ltr">
# [1] <head>\n<meta http-equiv="Content-Type" content="text/html; charset=UTF-8 ...
# [2] <body class="mediawiki ltr sitedir-ltr mw-hide-empty-elt ns-0 ns-subject  ...

# %% [markdown]
# Note that this HTML page at least contains three child `<table>` nodes under the root HTML node. So, you will need to use `html_nodes(root_node, "table")` function to get all its child `<table>` nodes:
#
# ```
# <html>
#   <table>(table1)</table>
#   <table>(table2)</table>
#   <table>(table3)</table>
#   ...
# </html>
# ```

# %% [markdown]
# table_nodes <- html_nodes(root_node, "table")

# %%
table_nodes <- html_nodes(root_node, "table")
table_nodes
# Out:
# {xml_nodeset (6)}
# [1] <table class="box-Split plainlinks metadata ambox ambox-move" role="prese ...
# [2] <table class="box-Overlinked plainlinks metadata ambox ambox-style" role= ...
# [3] <table class="wikitable sortable" style="text-align:left"><tbody>\n<tr>\n ...
# [4] <table class="nowraplinks mw-collapsible autocollapse navbox-inner" style ...
# [5] <table class="nowraplinks navbox-subgroup" style="border-spacing:0"><tbod ...
# [6] <table class="nowraplinks navbox-subgroup" style="border-spacing:0"><tbod ...

# %% [markdown]
# You can use a `for` loop to print each table, and then you will see that the actual the bike sharing table is the second element `table_nodes[[2]]`.

# %% [markdown]
# Next, you need to convert this HTML table into a data frame using the `html_table()` function. You may choose to include `fill = TRUE` argument to fill any empty table rows/columns.

# %%
# Convert the bike-sharing system table into a dataframe
bikes<-table_nodes[[3]]
bike<-html_table(bikes,fill = TRUE)
bike
# Out:
#     Country       City
# 1   Albania       Tirana[5]
# 2   Argentina     Mendoza[6]
# 3   Argentina     San Lorenzo, Santa Fe
# 4   Argentina     Buenos Aires[7][8]
# 5   Argentina     Rosario
# 6   Australia     Melbourne[12]
# 7   Australia     Brisbane[14][15]
# 8   Australia     Melbourne
# 9   Australia     Sydney
# 10  Australia     Sydney
# 11  Australia     Sydney
# 12  Austria       Vienna
# 13  Austria       Burgenland
# 14  Austria       Lower Austria[18]
# 15  Austria       Salzburg
# 16  Austria       Vienna
# 17  Austria       Vorarlberg
# 18  Bangladesh    Dhaka
# 19  Belgium       Different locations[19]
# 20  Belgium       Namur[22]
# 21  Belgium       Antwerp
# 22  Belgium       Brussels[25]
# 23  Brazil        Salvador[27]
# 24  Brazil        Belo Horizonte[28]
# 25  Brazil        Fortaleza
# 26  Brazil        João Pessoa[29]
# 27  Brazil        (Pedro de) Toledo[30]
# 28  Brazil        Rio de Janeiro[31]
# 29  Brazil        São Paulo[32]
# 30  Brazil        Sorocaba[33]
# ... ...           ...
# 486 United States Fullerton, California
# 487 United States Hoboken, New Jersey[304]
# 488 United States Houston, Texas[305][306]
# 489 United States Jersey City[308]
# 490 United States Kailua, Hawaii[309][310]
# 491 United States Kansas City, Missouri[311]
# 492 United States Kona District, Hawaii
# 493 United States Lansing, MI
# 494 United States Lincoln, Nebraska[313]
# 495 United States Los Angeles
# 496 United States Madison, Wisconsin[314]
# 497 United States Milwaukee, Wisconsin[315][316]
# 498 United States Minneapolis, Minnesota and Saint Paul, Minnesota[317][318]
# 499 United States Oklahoma City, Oklahoma[319]
# 500 United States Omaha, Nebraska[320]
# 501 United States Philadelphia, Pennsylvania[321][322]
# 502 United States Phoenix, Arizona
# 503 United States Pittsburgh, Pennsylvania
# 504 United States Portland, Oregon
# 505 United States Portland, Oregon
# 506 United States Salt Lake City, Utah[325]
# 507 United States San Antonio, Texas[326]
# 508 United States San Diego[327]
# 509 United States San Francisco Bay Area
# 510 United States San Francisco Bay Area[328]
# 511 United States Santa Monica, California[329]
# 512 United States Savannah, Georgia[330]
# 513 United States Seattle, Washington[331]
# 514 United States Spartanburg, South Carolina[332]
# 515 United States St. Paul
#     Name                        System
# 1   Ecovolis
# 2   Metrobici
# 3   Biciudad                    Biciudad
# 4   Ecobici                     Serttel Brasil[9]
# 5   Mi Bici Tu Bici[11]
# 6   Melbourne Bike Share        PBSC & 8D
# 7   CityCycle                   3 Gen. Cyclocity
# 8   oBike                       4 Gen. oBike
# 9   oBike                       4 Gen. oBike
# 10  Ofo                         4 Gen. Ofo
# 11  Reddy Go                    Reddy Go
# 12  Citybike Wien[16]           3 Gen. Cyclocity
# 13  LEIHRADL nextbike           3 Gen. nextbike
# 14  LEIHRADL nextbike           3 Gen. nextbike
# 15  nextbike                    3 Gen. nextbike
# 16  Viennabike                  2 Gen.
# 17                              3 Gen. nextbike
# 18  JoBike                      JoBike
# 19  dBlue-bike                  Blue-bike
# 20  Libiavelo                   3 Gen. Cyclocity
# 21  Velo Antwerp[23]            3 Gen. Clear CC
# 22  Villo!                      3 Gen. Cyclocity
# 23  Bike Salvador               tembici
# 24  Bikebh                      Mobilicidade
# 25  Bicicletar                  Mobilicidade
# 26  SAMBA                       Mobilicidade
# 27  Toopedalando                Toopedalando
# 28  Bike Rio                    tembici
# 29  Bikesampa                   tembici
# 30  Integrabike                 tembici
# ... ...                         ...
# 486 OCTA BikeShare              Bike Nation
# 487 Hudson Bike Share           3 Gen. nextbike
# 488 Houston B-cycle             3 Gen. B-Cycle
# 489 Citi Bike                   8D
# 490 Hawaii B-cycle              3 Gen. B-Cycle
# 491 Kansas City B-cycle         3 Gen. B-Cycle
# 492                             PBSC
# 493 Capital Community Bikeshare A2B Bikeshare
# 494 BikeLNK                     3 Gen. B-Cycle
# 495 Metro Bike Share            3 Gen. B-Cycle
# 496 Madison B-Cycle             3 Gen. B-Cycle
# 497 Bublr Bikes                 3 Gen. B-Cycle
# 498 Nice Ride                   PBSC & 8D
# 499 Spokies                     Spokies
# 500 Omaha B-Cycle               3 Gen. B-Cycle
# 501 Indego                      3 Gen. B-Cycle
# 502 Grid Bike Share             3 Gen. CycleHop and Social Bicycles
# 503 Healthy Ride PGH            3 Gen. nextbike
# 504 Biketown
# 505 Yellow Bike Project         1 Gen. WhiteBikes
# 506 SLC Bike Share              3 Gen. B-Cycle
# 507 San Antonio B-Cycle         3 Gen. B-Cycle
# 508 DecoBike                    DecoBike
# 509
# 510 Baywheels                   8D
# 511 Breeze Bike Share           3 Gen. CycleHop and Social Bicycles
# 512 CAT Bike                    3 Gen. B-Cycle
# 513 Pronto Cycle Share          8D
# 514 Spartanburg B-Cycle         3 Gen. B-Cycle
# 515 Yellow Bike Project         1 Gen. w/ BikeCard
#     Operator
# 1
# 2
# 3
# 4   Bike In Baires Consortium.[10]
# 5
# 6   Motivate
# 7   JCDecaux
# 8
# 9
# 10
# 11
# 12  JCDecaux Gewista
# 13
# 14
# 15
# 16  Association and city council
# 17
# 18
# 19  Blue-Mobility
# 20  JCDecaux
# 21  Service2Cities (subsidiary of Clear Channel Belgium)
# 22  JCDecaux
# 23
# 24
# 25
# 26
# 27
# 28
# 29
# 30
# ... ...
# 486
# 487
# 488
# 489 Motivate
# 490
# 491
# 492
# 493
# 494
# 495
# 496
# 497
# 498
# 499
# 500
# 501
# 502
# 503
# 504
# 505 Yellow Bike Project
# 506
# 507
# 508 JCDecaux
# 509
# 510 Motivate
# 511
# 512
# 513 Motivate
# 514
# 515 volunteers and city council
#     Launched                                Discontinued         Stations
# 1   March 2011                                                   8
# 2   2014                                                         2
# 3   27 November 2016                                             8
# 4   2010                                                         400
# 5   2 December 2015                                              47
# 6   June 2010                               30 November 2019[13] 53
# 7   September 2010                                               150
# 8   July 2017                               July 2018            dockless
# 9   July 2017                               July 2018            dockless
# 10  October 2017                                                 dockless
# 11  July 2017
# 12  June 2003                                                    121
# 13  2009                                                         40
# 14  2009                                                         295
# 15  2011
# 16  April 2002                              November 2002        200
# 17  2009                                                         14
# 18  2018                                                         05
# 19  1 May 2011                                                   70 (2021)[20]
# 20  21 April 2012                                                24
# 21  9 June 2011                                                  305 (2021)
# 22  19 May 2009 (earlier system since 2006)                      346
# 23  2013                                                         23
# 24  2014                                                         40
# 25  15 December 2014                                             80
# 26                                                               3
# 27  2011                                                         6
# 28  2011                                                         60
# 29  2012                                                         241
# 30  2012                                                         15
# ... ...                                     ...                  ...
# 486 6 January 2014                                               10
# 487 September 2015                                               29
# 488 2012                                                         126[307]
# 489 September 2015                                               50
# 490 2011                                                         2
# 491 2012                                                         30
# 492 2016                                                         3
# 493 2014                                                         8
# 494 2018                                                         19
# 495 7 July 2016                                                  207
# 496 2011                                                         39
# 497 2014                                                         87
# 498 2010                                                         171
# 499 2012                                                         7
# 500 2011                                                         5
# 501 23 April 2015                                                105
# 502 25 November 2014                                             40
# 503 2015                                                         50
# 504 19 July 2016                                                 100
# 505 1994[323]                               1997[324]
# 506 2013                                                         12
# 507 2011                                                         68
# 508 February 2015                                                180
# 509 2013
# 510 June 2017                                                    550
# 511 13 August 2015                                               80
# 512 24 January 2014                                              2
# 513 13 October 2014                         31 March 2017        50
# 514 2011                                                         5
# 515 1997
#     Bicycles        Daily ridership
# 1   200
# 2   40
# 3   80
# 4   4000            21917
# 5   480
# 6   676
# 7   2000
# 8   1250
# 9   1250
# 10  600
# 11  2000
# 12  1500            2800[17]
# 13
# 14  1300
# 15
# 16  1500
# 17  70
# 18  300
# 19  1790 (2019)[21]
# 20  200
# 21  4200 (2021)     7010[24]
# 22  4115[26]
# 23
# 24  400
# 25  800
# 26  20
# 27  60
# 28  300
# 29  600
# 30  120
# ... ...             ...
# 486 75
# 487 250
# 488 1000
# 489 500
# 490 12
# 491 300
# 492 30
# 493 20              Closed[312]
# 494 100
# 495 1700
# 496 350
# 497 400+
# 498 1833
# 499 100
# 500 35
# 501 1000
# 502 500
# 503 500
# 504 1000
# 505 1000
# 506 100
# 507 600
# 508 1800
# 509
# 510 7000
# 511 500
# 512 16
# 513 500
# 514 40
# 515

# %% [markdown]
# Summarize the bike sharing system data frame

# %%
# Summarize the dataframe
summary(bike)
# Out:
#    Country              City               Name              System
#  Length:515         Length:515         Length:515         Length:515
#  Class :character   Class :character   Class :character   Class :character
#  Mode  :character   Mode  :character   Mode  :character   Mode  :character
#    Operator           Launched         Discontinued         Stations
#  Length:515         Length:515         Length:515         Length:515
#  Class :character   Class :character   Class :character   Class :character
#  Mode  :character   Mode  :character   Mode  :character   Mode  :character
#    Bicycles         Daily ridership
#  Length:515         Length:515
#  Class :character   Class :character
#  Mode  :character   Mode  :character

# %% [markdown]
# Export the data frame as a csv file called `raw_bike_sharing_systems.csv`

# %%
# Export the dataframe into a csv file
write.csv(bike,file="raw_bike_sharing_systems.csv",row.names=TRUE)

# %% [markdown]
# For more details about webscraping with `rvest`, please refer to the previous webscraping notebook here:
#
# [Webscraping in R](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-RP0101EN-Coursera/v2/M4\_Working_With_Data/lab3\_jupyter_webscraping.ipynb)

# %% [markdown]
# ## Authors
#
# <a href="https://www.linkedin.com/in/yan-luo-96288783/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkRP0321ENSkillsNetwork25371262-2021-01-01" target="_blank">Yan Luo</a>

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# ## Change Log
#
# | Date (YYYY-MM-DD) | Version | Changed By | Change Description      |
# | ----------------- | ------- | ---------- | ----------------------- |
# | 2021-04-05        | 0.1     | Yan        | Initial version created |
# |                   |         |            |                         |
# |                   |         |            |                         |
#
# ## <h3 align="center"> © IBM Corporation 2021. All rights reserved. <h3/>
